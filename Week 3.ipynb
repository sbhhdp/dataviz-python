# %% [markdown]
# # Subplots

# %%
# %matplotlib notebook 

import matplotlib.pyplot as plt
import numpy as np

# %%
plt.subplot(1, 2, 1)
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">

# %%
plt.figure()
plt.subplot(1, 2, 1 )
linear_data = np.array([1, 2, 3, 4 ,5 , 6, 7, 8])
plt.plot(linear_data, '-o')
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">

# %%
exponential_data = linear_data**2
plt.subplot(1, 2, 2)
plt.plot(exponential_data , '-o')

# %%
plt.figure()
plt.subplot(1, 2, 1)
plt.plot(exponential_data, '-o')
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">

# %%
plt.figure()
ax1 = plt.subplot(1, 2, 1)
ax1.plot(linear_data, '-o')
ax2 = plt.subplot(1, 2, 2, sharey = ax1)
plt.plot(exponential_data, '-o')
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">

# %%
fig, ((ax1, ax2, ax3), (ax4, ax5, ax6), (ax7, ax8, ax9)) = plt.subplots(3, 3 , sharex = True, sharey = True)
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">

# %%
ax5.plot(linear_data, '-o');

# %%
ax6.plot(exponential_data, '-o');

# %%
plt.gcf().get_axes()

# %%
for ax in plt.gcf().get_axes():
    for label in (ax.get_xticklabels() + ax.get_yticklabels()):
        label.set_visible(True)

# %%
plt.gcf().canvas.draw()

# %%
f, ax = plt.subplots(3, 3, sharex=True, sharey=True)
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">

# %%
axs = ax.flatten()

# %%
for cax in axs:          #Works
    cax.tick_params(labelleft=True, labelbottom=True)

# %%
for cAx in axs:         #Works
        cAx.xaxis.set_tick_params(labelbottom=True)
        cAx.yaxis.set_tick_params(labelbottom=True)

# %%
plt.gcf().canvas.draw()

# %%
f, ax = plt.subplots(3, 3, sharex=True, sharey=True)
for cAx in ax.flatten():
    cAx.tick_params(labelbottom=True, labelleft=True)
#         cAx.xaxis.set_tick_params(labelbottom=True)
#         cAx.yaxis.set_tick_params(labelbottom=True)
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">

# %%
f.subplots_adjust(hspace = 0.5, wspace = 0.5)

# %%
f.tight_layout()

# %% [markdown]
# # Histograms

# %%
np.random.normal(0, 1, 10)
# Out:
# array([-0.2783944 ,  1.37768142,  0.2241698 ,  0.80382549, -1.05528327,
#        -1.09111588, -0.21071016,  0.72779457,  1.76298501, -1.08236797])

# %%
fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(2, 2, sharex = True)
axs = [ax1, ax2, ax3, ax4]
for n in range(len(axs)):
    sample_size = 10**(n+1)
    sample = np.random.normal(0, 1, sample_size)
    axs[n].hist(sample)
    axs[n].set_title(f'sample size {sample_size}')
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">

# %%
fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(2, 2, sharex = True)
axs = [ax1, ax2, ax3, ax4]

for n in range(len(axs)):
    sample_size = 10 ** (n+1)
    sample = np.random.normal(0, 1, sample_size)
    axs[n].hist(sample, bins = 100)
    axs[n].set_title(f'n = {sample_size}')
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">

# %%
fig, ax = plt.subplots(2, 2, sharex = True)
for n in range(len(ax.flatten())):
    sample_size = 10**(n+1)
    sample = np.random.normal(0, 1, sample_size)
    ax.flatten()[n].hist(sample)
    ax.flatten()[n].set_title(f'n = {sample_size}')
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">

# %%
fig, ax = plt.subplots(2, 2, sharex = True)
for n in range(len(ax.flatten())):
    sample_size = 10**(n+1)
    sample  = np.random.normal(0, 1, sample_size)
    ax.flatten()[n].hist(sample, bins = 15)
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">

# %%
import matplotlib.gridspec as gridspec

# %%
gspec = gridspec.GridSpec(3, 3)

top_histogram = plt.subplot(gspec[0, 1:])
side_histogram = plt.subplot(gspec[1:, 0])
lower_right = plt.subplot(gspec[1:, 1:])

# %%
y = np.random.normal(0, 1, 10000)
x = np.random.random(10000)

top_histogram.hist(x, bins = 100)
s = side_histogram.hist(y, bins = 100, orientation = 'horizontal')
lower_right.scatter(x, y)

# %%
top_histogram.clear()
top_histogram.hist(y, density=True, bins = 100)
side_histogram.clear()
side_histogram.hist(x, density=True, bins = 100, orientation = 'horizontal')
side_histogram.invert_xaxis()

# %%
for ax in [top_histogram, lower_right]:
    ax.set_xlim(-5, 5)
    
for ax in [side_histogram, lower_right]:
    ax.set_ylim(0, 1)

# %% [markdown]
# # Box And Whisker Plots

# %%
import pandas as pd

# %%
normal_sample = np.random.normal(0.0, 1, 10000)
random_sample = np.random.random(10000)
gamma_sample = np.random.gamma(2, size = 10000)

df = pd.DataFrame({'normal': normal_sample, 'random' : random_sample, 'gamma' : gamma_sample})

# %%
df
# Out:
#         normal    random     gamma
# 0    -0.038498  0.360911  0.297017
# 1     0.056898  0.597641  0.632418
# 2     0.646766  0.244305  0.754850
# 3    -0.615387  0.399617  3.768531
# 4    -0.433804  0.773536  1.072341
# ...        ...       ...       ...
# 9995  0.701759  0.047557  1.273663
# 9996 -1.213163  0.515630  1.666020
# 9997 -2.044961  0.411175  4.256694
# 9998 -1.013761  0.924148  1.973310
# 9999  0.723495  0.903217  0.705824
#
# [10000 rows x 3 columns]

# %%
df.describe()
# Out:
#              normal        random         gamma
# count  10000.000000  10000.000000  10000.000000
# mean      -0.010504      0.499513      1.994733
# std        1.000130      0.289944      1.397537
# min       -3.653175      0.000030      0.023304
# 25%       -0.685770      0.249351      0.962885
# 50%        0.006871      0.504779      1.681614
# 75%        0.653883      0.747443      2.680897
# max        3.761564      0.999905     12.584534

# %%
plt.figure()

_ = plt.boxplot(df['normal'], whis = 'range')
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">

# %%
plt.clf()

_ = plt.boxplot([df['normal'], df['random'], df['gamma']], whis = 'range')

# %%
plt.figure()
_ = plt.hist(df['gamma'], bins = 100)
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">

# %%
import mpl_toolkits.axes_grid1.inset_locator as mpl_il

plt.figure()
plt.boxplot([df['normal'], df['random'], df['gamma']], whis = 'range')
ax2 = mpl_il.inset_axes(plt.gca(), height = '40%', width = '60%', loc = 2)
ax2.hist(df['gamma'], bins = 100)
ax2.margins(x = 0.5)
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">

# %%
ax2.yaxis.tick_right()

# %% [markdown]
# # Heatmaps

# %%
plt.figure()
y = np.random.normal(0, 1, 10000)
x =  np.random.random(10000)
_ = plt.hist2d(x, y, bins = 25)
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">

# %%
plt.figure()
_ = plt.hist2d(x, y, bins = 100)
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">

# %%
plt.colorbar()

# %% [markdown]
# # Animation

# %%
import matplotlib.animation as animation

n = 1000
x = np.random.randn(n)

# %%
def update(curr):
    if curr  == n:
        a.event_source.stop()
    plt.cla()
    bins = np.arange(-4, 4, 0.5)
    plt.hist(x[:curr], bins = bins)
    plt.axis([-4, 4, 0, 200])
    plt.gca().set_title('Sampling the normal distribution')
    plt.gca().set_ylabel('Frequency')
    plt.gca().set_xlabel('Value')
    plt.annotate(f'n = {curr}', [3, 27])

# %%
fig = plt.figure()
a = animation.FuncAnimation(fig, update, interval = 50)
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">

# %% [markdown]
# # Interactivity

# %%
plt.figure()
data = np.random.rand(10)
plt.plot(data)

def onclick(event):
    plt.cla()
    plt.plot(data)
    plt.gca().set_title(f'Event at pixels {event.x}, {event.y} and data {event.xdata :.2f}, {event.ydata :.2f}')
                        
plt.gcf().canvas.mpl_connect('button_press_event', onclick)
# Out:
# <img src="data:image/png;base64,..." width="640">
# 6

# %%
 from random import shuffle

# %%
origins = ['Brazil', 'China', 'USA', 'India', 'UK', 'Canada', 'Germany', 'Iraq', 'France',  'Mexico']
shuffle(origins)

df = pd.DataFrame({'height': np.random.rand(10), 'weight': np.random.rand(10), 'origin' : origins})
df
# Out:
#      height    weight   origin
# 0  0.152332  0.314222   Brazil
# 1  0.551038  0.784551   France
# 2  0.614629  0.667803   Mexico
# 3  0.118424  0.166806    China
# 4  0.224924  0.628091       UK
# 5  0.960657  0.342822   Canada
# 6  0.148642  0.023988  Germany
# 7  0.318769  0.002379     Iraq
# 8  0.771137  0.729653      USA
# 9  0.972950  0.812817    India

# %%
plt.figure()
plt.scatter( df['height'], df['weight'], picker = 5)
plt.gca().set_ylabel('Weight')
plt.gca().set_xlabel('Height')
def onpick():
    origin = df.iloc[event.ind[0]]['origin']
    plt.gca().set_title(f'Selected item came from {origin}')
    
plt.gcf().canvas.mpl_connect('pick_event', onpick);
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
def onpick():
    origin = df.iloc[event.ind[0]]['origin']
    plt.gca().set_title(f'Selected item came from {origin}')
    
plt.gcf().canvas.mpl_connect('pick_event', onpick)
# Out:
# 7
